# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_csv('car_sales_dataset.csv')
df.head(10)
# Out:
#          Date        Salesperson       Customer Name  Customer Age  \
# 0  2019-04-02         Mary Simon   Kristin Blackwell            42
# 1  2018-04-13      Nancy Mercado         Diana Black            65
# 2  2021-01-31        Pamela King        Craig Powers            67
# 3  2020-09-30   Elizabeth Ashley       Jade Williams            69
# 4  2020-07-03        Brian Cline  Nicholas Fernandez            50
# 5  2019-07-26         Alan Ramos        John Nichols            41
# 6  2019-02-24     Rebekah Turner     Kenneth Jimenez            25
# 7  2024-02-12   Jessica Schaefer      Melissa Newman            23
# 8  2018-12-23        Brian Cline       Mark Robinson            24
# 9  2024-08-15  Christopher Scott        Susan Flores            56
#
#   Customer Gender Car Make   Car Model  Car Year  Quantity  Sale Price  ...  \
# 0            Male  Hyundai    Santa Fe      2019         1    25949.00  ...
# ...

# %%
df.columns
# Out:
# Index(['Date', 'Salesperson', 'Customer Name', 'Customer Age',
#        'Customer Gender', 'Car Make', 'Car Model', 'Car Year', 'Quantity',
#        'Sale Price', 'Cost', 'Profit', 'Discount', 'Payment Method',
#        'Commission Rate', 'Commission Earned', 'Sales Region', 'Sale Year',
#        'Sale Month', 'Sale Quarter', 'Day of Week', 'Season'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000668 entries, 0 to 1000667
# Data columns (total 22 columns):
#  #   Column             Non-Null Count    Dtype
# ---  ------             --------------    -----
#  0   Date               1000668 non-null  object
#  1   Salesperson        1000668 non-null  object
#  2   Customer Name      1000668 non-null  object
#  3   Customer Age       1000668 non-null  int64
#  4   Customer Gender    1000668 non-null  object
#  5   Car Make           1000668 non-null  object
#  6   Car Model          1000668 non-null  object
#  7   Car Year           1000668 non-null  int64
#  8   Quantity           1000668 non-null  int64
#  9   Sale Price         1000668 non-null  float64
#  10  Cost               1000668 non-null  float64
#  11  Profit             1000668 non-null  float64
#  12  Discount           1000668 non-null  float64
#  13  Payment Method     1000668 non-null  object
#  14  Commission Rate    1000668 non-null  float64
# ...

# %%
df.describe()
# Out:
#        Customer Age      Car Year      Quantity    Sale Price          Cost  \
# count  1.000668e+06  1.000668e+06  1.000668e+06  1.000668e+06  1.000668e+06
# mean   4.502699e+01  2.020998e+03  2.120985e+00  8.664273e+04  7.268286e+04
# std    1.472792e+01  1.999433e+00  6.081103e-01  1.724110e+05  3.632967e+05
# min    2.000000e+01  2.018000e+03  1.000000e+00  9.508000e+03  6.969890e+03
# 25%    3.200000e+01  2.019000e+03  2.000000e+00  5.496180e+04  4.364586e+04
# 50%    4.500000e+01  2.021000e+03  2.000000e+00  7.390822e+04  5.932850e+04
# 75%    5.800000e+01  2.023000e+03  3.000000e+00  1.072945e+05  8.300239e+04
# max    7.000000e+01  2.024000e+03  3.000000e+00  2.821159e+07  4.139586e+07
#
#              Profit      Discount  Commission Rate  Commission Earned  \
# count  1.000668e+06  1.000668e+06     1.000668e+06       1.000668e+06
# mean   1.395987e+04  5.998358e-02     7.118896e-02       5.607642e+03
# std    2.130789e+05  3.756358e-02     1.744452e-02       3.577184e+03
# ...

# %%
duplicate=df.duplicated().sum()
duplicate
# Out:
# 0

# %%
df.isnull().sum()
# Out:
# Date                 0
# Salesperson          0
# Customer Name        0
# Customer Age         0
# Customer Gender      0
# Car Make             0
# Car Model            0
# Car Year             0
# Quantity             0
# Sale Price           0
# Cost                 0
# Profit               0
# Discount             0
# Payment Method       0
# Commission Rate      0
# Commission Earned    0
# Sales Region         0
# Sale Year            0
# Sale Month           0
# Sale Quarter         0
# Day of Week          0
# Season               0
# dtype: int64

# %%
df['Car Make'].unique()
# Out:
# array(['Hyundai', 'Ford', 'Kia', 'BMW', 'Audi', 'Nissan', 'Toyota',
#        'Chevrolet', 'Mercedes', 'Honda'], dtype=object)

# %%
df['Car Model'].unique()
# Out:
# array(['Santa Fe', 'Explorer', 'Telluride', '5 Series', 'A6', 'A4',
#        'Pathfinder', 'Escape', 'Highlander', 'Tucson', 'Tahoe', 'C-Class',
#        'Altima', 'Accord', 'Maxima', 'F-150', 'Q5', 'Prius', 'A8', 'RAV4',
#        'Sonata', 'Camry', 'Kona', 'Sorento', 'Elantra', 'Rogue',
#        'Equinox', 'Q7', 'Sportage', 'CR-V', 'Sentra', 'Pilot', 'E-Class',
#        'GLC', 'GLE', 'Optima', 'Odyssey', 'Mustang', 'X3', 'Forte',
#        '7 Series', '3 Series', 'Silverado', 'Corolla', 'S-Class', 'Civic',
#        'Focus', 'Malibu', 'Camaro', 'X5'], dtype=object)

# %%
df['Make_Model'] = df['Car Make'] +' ' +df['Car Model']
df['Make_Model']
# Out:
# 0           Hyundai Santa Fe
# 1              Ford Explorer
# 2              Kia Telluride
# 3               BMW 5 Series
# 4                    Audi A6
#                  ...
# 1000663         Mercedes GLC
# 1000664    Nissan Pathfinder
# 1000665     Mercedes C-Class
# 1000666          Kia Sorento
# 1000667        Nissan Maxima
# Name: Make_Model, Length: 1000668, dtype: object

# %%
m_m = df['Make_Model'].unique()
m_m
# Out:
# array(['Hyundai Santa Fe', 'Ford Explorer', 'Kia Telluride',
#        'BMW 5 Series', 'Audi A6', 'Audi A4', 'Nissan Pathfinder',
#        'Ford Escape', 'Toyota Highlander', 'Hyundai Tucson',
#        'Chevrolet Tahoe', 'Mercedes C-Class', 'Nissan Altima',
#        'Honda Accord', 'Nissan Maxima', 'Ford F-150', 'Audi Q5',
#        'Toyota Prius', 'Audi A8', 'Toyota RAV4', 'Hyundai Sonata',
#        'Toyota Camry', 'Hyundai Kona', 'Kia Sorento', 'Hyundai Elantra',
#        'Nissan Rogue', 'Chevrolet Equinox', 'Audi Q7', 'Kia Sportage',
#        'Honda CR-V', 'Nissan Sentra', 'Honda Pilot', 'Mercedes E-Class',
#        'Mercedes GLC', 'Mercedes GLE', 'Kia Optima', 'Honda Odyssey',
#        'Ford Mustang', 'BMW X3', 'Kia Forte', 'BMW 7 Series',
#        'BMW 3 Series', 'Chevrolet Silverado', 'Toyota Corolla',
#        'Mercedes S-Class', 'Honda Civic', 'Ford Focus',
#        'Chevrolet Malibu', 'Chevrolet Camaro', 'BMW X5'], dtype=object)

# %%
id = []
tid =np.linspace(1001,1050,50)
for x in tid:
    x= int(x)
    id.append(x)
print(id)
# Out:
# [1001, 1002, 1003, 1004, 1005, 1006, 1007, 1008, 1009, 1010, 1011, 1012, 1013, 1014, 1015, 1016, 1017, 1018, 1019, 1020, 1021, 1022, 1023, 1024, 1025, 1026, 1027, 1028, 1029, 1030, 1031, 1032, 1033, 1034, 1035, 1036, 1037, 1038, 1039, 1040, 1041, 1042, 1043, 1044, 1045, 1046, 1047, 1048, 1049, 1050]

# %%
c_df = pd.DataFrame(['Hyundai Santa Fe', 'Ford Explorer', 'Kia Telluride',
       'BMW 5 Series', 'Audi A6', 'Audi A4', 'Nissan Pathfinder',
       'Ford Escape', 'Toyota Highlander', 'Hyundai Tucson',
       'Chevrolet Tahoe', 'Mercedes C-Class', 'Nissan Altima',
       'Honda Accord', 'Nissan Maxima', 'Ford F-150', 'Audi Q5',
       'Toyota Prius', 'Audi A8', 'Toyota RAV4', 'Hyundai Sonata',
       'Toyota Camry', 'Hyundai Kona', 'Kia Sorento', 'Hyundai Elantra',
       'Nissan Rogue', 'Chevrolet Equinox', 'Audi Q7', 'Kia Sportage',
       'Honda CR-V', 'Nissan Sentra', 'Honda Pilot', 'Mercedes E-Class',
       'Mercedes GLC', 'Mercedes GLE', 'Kia Optima', 'Honda Odyssey',
       'Ford Mustang', 'BMW X3', 'Kia Forte', 'BMW 7 Series',
       'BMW 3 Series', 'Chevrolet Silverado', 'Toyota Corolla',
       'Mercedes S-Class', 'Honda Civic', 'Ford Focus',
    'Chevrolet Malibu', 'Chevrolet Camaro', 'BMW X5'])
c_df.head()
# Out:
#                   0
# 0  Hyundai Santa Fe
# 1     Ford Explorer
# 2     Kia Telluride
# 3      BMW 5 Series
# 4           Audi A6

# %%
c_df.rename(columns={0: 'Car_Make_model'}, inplace=True)
c_df.head()
# Out:
#      Car_Make_model
# 0  Hyundai Santa Fe
# 1     Ford Explorer
# 2     Kia Telluride
# 3      BMW 5 Series
# 4           Audi A6

# %%
c_df[['Make', 'Model']] = c_df['Car_Make_model'].str.split(' ', n=1, expand=True)
c_df.head()
# Out:
#      Car_Make_model     Make      Model
# 0  Hyundai Santa Fe  Hyundai   Santa Fe
# 1     Ford Explorer     Ford   Explorer
# 2     Kia Telluride      Kia  Telluride
# 3      BMW 5 Series      BMW   5 Series
# 4           Audi A6     Audi         A6

# %%
c_df['Car_id'] = id
col = c_df.pop('Car_id')
c_df.insert(0, 'Car_id', col,0)
c_df.head()
# Out:
#    Car_id    Car_Make_model     Make      Model
# 0    1001  Hyundai Santa Fe  Hyundai   Santa Fe
# 1    1002     Ford Explorer     Ford   Explorer
# 2    1003     Kia Telluride      Kia  Telluride
# 3    1004      BMW 5 Series      BMW   5 Series
# 4    1005           Audi A6     Audi         A6

# %%
c_df.to_csv("Car_table.csv",index = False)
